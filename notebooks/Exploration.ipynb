# %% [markdown]
# # Importing the Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
import os

pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %% [markdown]
# # Loading Data

# %% [markdown]
# ## Load Acura Data

# %%
# Importing the data
def import_data(data_name):
    file_folder = r"C:\Users\PSALISHOL\Documents\My Projects\Car Prediction\data\interim"
    filepath = os.path.join(file_folder, data_name+".csv")
    
    # Reading the file
    data = pd.read_csv(filepath)
    data = data.drop("Unnamed: 0",axis=1)
    
    data["City"] = data["City"].apply(lambda city: city.replace("LA", "Los Angeles"))
    
    return data

# Importing the data
Acura = import_data("Acura_model_cl")
Acura.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\PSALIS~1\AppData\Local\Temp/ipykernel_16952/1523781567.py in <module>
#      13
#      14 # Importing the data
# ---> 15 Acura = import_data("Acura_model_cl")
#      16 Acura.info()
#
# C:\Users\PSALIS~1\AppData\Local\Temp/ipykernel_16952/1523781567.py in import_data(data_name)
#       5
#       6     # Reading the file
# ----> 7     data = pd.read_csv(filepath)
#       8     data = data.drop("Unnamed: 0",axis=1)
#       9
#
# ...

# %%
Acura.isnull().sum()
# Out:
# year                             0
# mileage                          0
# price                            0
# fueltype                       145
# Drivetrain                      25
# Transmission                    65
# State                            0
# Zip                              0
# City                             0
# Engine size                    603
# Avg mpg                         65
# Model                            0
# Vehicle Make                     0
# Heated Seats                     0
# Keyless Start                    0
# Bluetooth                        0
# Alloy Wheels                     0
# Sunroof/Moonroof                 0
# Brake Assist                     0
# Stability Control                0
# Leather Seats                    0
# Adaptive Cruise Control          0
# Navigation System                0
# Power Liftgate                   0
# Premium Sound System             0
# Memory Seat                      0
# Apple CarPlay/Android Auto       0
# ...

# %%
Acura.head()
# Out:
#    year  mileage  price  fueltype Drivetrain Transmission State    Zip  \
# 0  2015    72528  12980  Gasoline        FWD    Automatic    IL  60056
# 1  2019    36182  41998  Gasoline        AWD    Automatic    WA  98036
# 2  2019    12775  44499  Gasoline        AWD    Automatic    WA  98037
# 3  2020    31175  31140  Gasoline        FWD    Automatic    TX  75093
# 4  2019    75689  34495  Gasoline        FWD    Automatic    TX  77573
#
#           City  Engine size  Avg mpg    Model Vehicle Make Heated Seats  \
# 0     Prospect          1.5     34.5  Hardtop         MINI          Yes
# 1     Lynnwood          2.0     23.5      RDX        Acura           No
# 2     Lynnwood          2.0     23.5      RDX        Acura          Yes
# 3        Plano          2.4     28.0      TLX        Acura          Yes
# 4  League City          2.0     24.5      RDX        Acura           No
#
#   Keyless Start Bluetooth Alloy Wheels Sunroof/Moonroof Brake Assist  \
# ...

# %% [markdown]
# ## Load Audi Data

# %%
# Importing the data
def import_data(data_name, info=False):
    file_folder = r"C:\Users\PSALISHOL\Documents\My Projects\Car Prediction\data\interim"
    filepath = os.path.join(file_folder, data_name+".csv")
    
    # Reading the file
    data = pd.read_csv(filepath)
    data = data.drop("Unnamed: 0",axis=1)
    
    data["City"] = data["City"].apply(lambda city: city.replace("LA", "Los Angeles"))
    
    if info is True:
        Audi.info()
    return data
Audi = import_data("Audi_cl", info=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8318 entries, 0 to 8317
# Data columns (total 42 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   year                         8318 non-null   int64
#  1   mileage                      8318 non-null   int64
#  2   price                        8318 non-null   int64
#  3   fueltype                     7451 non-null   object
#  4   Drivetrain                   8171 non-null   object
#  5   Transmission                 7081 non-null   object
#  6   State                        8318 non-null   object
#  7   Zip                          8318 non-null   object
#  8   City                         8318 non-null   object
#  9   Engine size                  7361 non-null   float64
#  10  Avg mpg                      7803 non-null   float64
#  11  Model                        8318 non-null   object
#  12  Vehicle Make                 8318 non-null   object
# ...

# %%
# Dealing with missing values 
def missing_val(data):
    cat_fea_missing = [feature for feature in data.columns if 
                       data[feature].dtype == object and data[feature].isnull().sum() >0]
    num_fea_missing = [feature for feature in data.columns if 
                       data[feature].dtype != object and data[feature].isnull().sum() >0]
    for feature in cat_fea_missing:
        data[feature] = data[feature].fill(data[feature].mode(),inplace=True)
    for feature in num_fea_missing:
        data[feature] = data[feature].filln
# Out:
# Gasoline    7046
# Hybrid       170
# Electric     138
# Diesel        97
# Name: fueltype, dtype: int64

# %%
# Importing the data and recleaning the data
def import_data(data_name, info=False):
    file_folder = r"C:\Users\PSALISHOL\Documents\My Projects\Car Prediction\data\interim"
    filepath = os.path.join(file_folder, data_name+".csv")
    
    # Reading the file
    data = pd.read_csv(filepath)
    data = data.drop("Unnamed: 0",axis=1)
    
    data["City"] = data["City"].apply(lambda city: city.replace("LA", "Los Angeles"))
    
    if info is True:
        Audi.info()
    return data
Bmw = import_data("BMW_cl", info=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8318 entries, 0 to 8317
# Data columns (total 42 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   year                         8318 non-null   int64
#  1   mileage                      8318 non-null   int64
#  2   price                        8318 non-null   int64
#  3   fueltype                     7451 non-null   object
#  4   Drivetrain                   8171 non-null   object
#  5   Transmission                 7081 non-null   object
#  6   State                        8318 non-null   object
#  7   Zip                          8318 non-null   object
#  8   City                         8318 non-null   object
#  9   Engine size                  7361 non-null   float64
#  10  Avg mpg                      7803 non-null   float64
#  11  Model                        8318 non-null   object
#  12  Vehicle Make                 8318 non-null   object
# ...

# %%
Bmw.head()
# Out:
#    year  mileage  price  fueltype Drivetrain Transmission State    Zip  \
# 0  2019    11323  43995  Gasoline        AWD    Automatic    IL  60622
# 1  2019    14613  60495  Gasoline        AWD    Automatic    CA  94103
# 2  2018    18066  32995  Gasoline        AWD    Automatic    GA  30076
# 3  2015    60021  23990  Gasoline        AWD    Automatic    NY  11021
# 4  2018    34787  39450  Gasoline        AWD    Automatic    NJ  07001
#
#          City  Engine size  Avg mpg Model Vehicle Make  \
# 0     Chicago          3.5     22.5   MDX        Acura
# 1   Francisco          3.0     23.0    X5          BMW
# 2  Alpharetta          2.0     26.0    X2          BMW
# 3  Great Neck          3.0     22.5    X5          BMW
# 4      Avenel          3.0     26.0   440          BMW
#
#   Adaptive Cruise Control Heated Seats Keyless Start Navigation System  \
# 0                     Yes          Yes           Yes               Yes
# ...

# %%
Bmw["fueltype"].value_counts()
# Out:
# Gasoline    8583
# Diesel        81
# Hybrid        19
# Electric       5
# Name: fueltype, dtype: int64

# %%
Bmw[feature].fillna()
